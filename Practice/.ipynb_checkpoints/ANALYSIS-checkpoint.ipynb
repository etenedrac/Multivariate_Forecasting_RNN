# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import spline
import scipy as sp
import scipy.signal as sg

# %% [markdown]
# # Accuracy training per batch

# %%
with open('./results/experiment1/run_EXPERIMENT_3_1-batch_loss.csv', 'r') as f:
    reader = csv.reader(f)
    lst = list(reader)

exp_1 = lst[1:]

with open('./results/experiment1/run_EXPERIMENT_3_1-batch_loss.csv', 'r') as f:
    reader = csv.reader(f)
    lst = list(reader)
exp_2 = lst[1:]

with open('./results/experiment1/run_EXPERIMENT_3_1-batch_loss.csv', 'r') as f:
    reader = csv.reader(f)
    lst = list(reader)

exp_3 = lst[1:]


lst[0]
# Out:
# ['Wall time', 'Step', 'Value']

# %%
print("Elapsed time for EXP1:",round((float(exp_1[len(exp_1)-1][0])-float(exp_1[0][0]))/60,1), "minutes")
# Out:
# Elapsed time for EXP1: 1.7 minutes

# %%
step_fnn1 = []
val_fnn1 = []
t_fnn1 = []
step_cnn1 = []
val_cnn1 = []
t_cnn1 = []
step_cnn2 = []
val_cnn2 = []
t_cnn2 = []
step_cnn3 = []
val_cnn3 = []
t_cnn3 = []

# for i in range(len(fnn_1)):
#     t_fnn1.append((float(fnn_1[i][0])-float(fnn_1[0][0]))/60)
#     step_fnn1.append(float(fnn_1[i][1]))
#     val_fnn1.append(float(fnn_1[i][2]))
    
for i in range(len(cnn_1)):
    t_cnn1.append((float(cnn_1[i][0])-float(cnn_1[0][0]))/60)
    step_cnn1.append(float(cnn_1[i][1]))
    val_cnn1.append(float(cnn_1[i][2]))
    
for i in range(len(cnn_2)):
    t_cnn2.append((float(cnn_2[i][0])-float(cnn_2[0][0]))/60)
    step_cnn2.append(float(cnn_2[i][1]))
    val_cnn2.append(float(cnn_2[i][2]))
    
for i in range(len(cnn_3)):
    t_cnn3.append((float(cnn_3[i][0])-float(cnn_3[0][0]))/60)
    step_cnn3.append(float(cnn_3[i][1]))
    val_cnn3.append(float(cnn_3[i][2]))

# %%
b, a = sg.butter(1, 0.1)

#y_fnn_1 = sg.filtfilt(b, a, val_fnn1)
y_cnn_1 = sg.filtfilt(b, a, val_cnn1)
y_cnn_2 = sg.filtfilt(b, a, val_cnn2)
y_cnn_3 = sg.filtfilt(b, a, val_cnn3)

plt.figure
# plt.plot(step_fnn1, val_fnn1, 'b', alpha=0.3, label='_nolegend_')
# plt.plot(step_fnn1, y_fnn_1, 'b')

plt.plot(step_cnn1, val_cnn1, 'r', alpha=0.3, label='_nolegend_')
plt.plot(step_cnn1, y_cnn_1, 'r')

plt.plot(step_cnn2, val_cnn2, 'g', alpha=0.3, label='_nolegend_')
plt.plot(step_cnn2, y_cnn_2, 'g')

plt.plot(step_cnn3, val_cnn3, 'm', alpha=0.3, label='_nolegend_')
plt.plot(step_cnn3, y_cnn_3, 'm')

plt.legend(('CNN 3+Dropouts+SGD','CNN 3+Dropouts+ADAM', 'CNN 3+Dropouts+RMSprop'), loc='best')
#plt.legend(('FNN','CNN 1','CNN 2','CNN 3'), loc='best')

plt.grid(True)

plt.xlabel('Epoch')
plt.ylabel('Epoch Validation Accuracy')
plt.savefig('epoch_val_loss.pdf')

# %%
1-max(val_cnn3)
# Out:
# 0.3658221960067749

# %%
b, a = sg.butter(1, 0.1)

# y_fnn_1 = sg.filtfilt(b, a, val_fnn1)
y_cnn_1 = sg.filtfilt(b, a, val_cnn1)
y_cnn_2 = sg.filtfilt(b, a, val_cnn2)
y_cnn_3 = sg.filtfilt(b, a, val_cnn3)

plt.figure
# plt.plot(t_fnn1, val_fnn1, 'b', alpha=0.3, label='_nolegend_')
# plt.plot(t_fnn1, y_fnn_1, 'b')

plt.plot(t_cnn1, val_cnn1, 'r', alpha=0.3, label='_nolegend_')
plt.plot(t_cnn1, y_cnn_1, 'r')

plt.plot(t_cnn2, val_cnn2, 'g', alpha=0.3, label='_nolegend_')
plt.plot(t_cnn2, y_cnn_2, 'g')

plt.plot(t_cnn3, val_cnn3, 'm', alpha=0.3, label='_nolegend_')
plt.plot(t_cnn3, y_cnn_3, 'm')


plt.legend(('CNN 3+Dropouts+SGD','CNN 3+Dropouts+ADAM', 'CNN 3+Dropouts+RMSprop'), loc='best')

plt.grid(True)

plt.xlabel('Time [min]')
plt.ylabel('')
plt.savefig('batch_time_loss.pdf')
